# %%
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib notebook
import statsmodels.api as sm

# %%
df = pd.read_excel (r'C:\Users\Administrator\Desktop\پروژه کارشناسی\sood o ziyan.xlsx', sheet_name='regression data')

# %%
print(df)
industry = np.array(df['industry'])
gdp = np.array(df['GDP'])
stock = np.array(df['stock'])
oil = np.array(df['oil'])
# Out:
#     year      stock           oil      industry           GDP
# 0   1383    6263066  5.305275e+07  2.570539e+05  1.631020e+06
# 1   1384    8009216  6.243791e+07  3.053284e+05  2.060757e+06
# 2   1385   16233560  7.096612e+07  3.671501e+05  2.486862e+06
# 3   1386   23402853  1.008425e+08  4.191496e+05  3.263077e+06
# 4   1387   19702816  6.162704e+07  5.041778e+05  3.893894e+06
# 5   1388   17312144  7.765991e+07  5.452452e+05  4.073179e+06
# 6   1389   28749790  1.076660e+08  6.437736e+05  4.990404e+06
# 7   1390   24515519  1.743687e+08  7.809667e+05  6.364369e+06
# 8   1391   45793006  2.095694e+08  1.060487e+06  7.283991e+06
# 9   1392   51322651  1.972223e+08  1.365487e+06  9.842619e+06
# 10  1393   38164655  1.014001e+08  1.583712e+06  1.126009e+07
# 11  1394    2178730  9.942847e+07  1.412440e+06  1.112903e+07
# 12  1395   32594857  1.764030e+08  1.564416e+06  1.272285e+07
# 13  1396  106905070  2.140196e+08  1.837174e+06  1.480710e+07

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(stock, oil, industry, c='red')
ax.view_init(azim=30)
plt.show()

# %%
print(stock.size)
X=[]
for i in range(0,14):
    X.append([stock[i],oil[i]])
print(X)
# Out:
# 14
# [[6263066, 53052750.912], [8009216, 62437910.44], [16233560, 70966118.72], [23402853, 100842468.04499999], [19702816, 61627042.260000005], [17312144, 77659908.0], [28749790, 107666028.8], [24515519, 174368700.0], [45793006, 209569422.0], [51322651, 197222256.0], [38164655, 101400141.0], [2178730, 99428472.0], [32594857, 176403000.0], [106905070, 214019630.0]]

# %%
results=sm.OLS(industry,X).fit()

# %%
results.params
# Out:
# array([0.00529197, 0.00586889])
